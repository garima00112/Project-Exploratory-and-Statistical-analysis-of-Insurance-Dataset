# %% [markdown]
# # Import Libaries

# %%
import pandas as pd         #for data manupulation
import numpy as np           #for numerical computation
import matplotlib.pyplot as plt  #for plotting graphs
# %matplotlib inline           
import scipy.stats as stats  #It has all probability distribution with many statistical functions
import seaborn as sns       #for data visualizations
import warnings             #for handling warnings
warnings.filterwarnings('ignore')  #to suppress the warnings

# %%
#Reading the csv file insurance
df= pd.read_csv('insurance.csv')
insured= df.copy()

# %%
insured.head(5)    #insured the top 5 rows
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
insured.tail(5)     #insured bottom 5 rows
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36

# %%
insured.info()    #it gives information about datatype of different columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   expenses  1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
insured.describe()  #this displays the various statistical measures of each numerical columns
# Out:
#                age          bmi     children      expenses
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.665471     1.094918  13270.422414
# std      14.049960     6.098382     1.205493  12110.011240
# min      18.000000    16.000000     0.000000   1121.870000
# 25%      27.000000    26.300000     0.000000   4740.287500
# 50%      39.000000    30.400000     1.000000   9382.030000
# 75%      51.000000    34.700000     2.000000  16639.915000
# max      64.000000    53.100000     5.000000  63770.430000

# %%
insured.shape   #get the size of the dataframe
print("Rows : ", insured.shape[0])
print("Columns: ", insured.shape[1])
# Out:
# Rows :  1338
# Columns:  7

# %%
insured.isnull().sum()      #to find out if there is any empty value
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# expenses    0
# dtype: int64

# %%
insured.columns      #finding all columns name
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'expenses'], dtype='object')

# %%
#Converting object datatype to categorical data type

insured['sex']= insured['sex'].astype("category")
insured['smoker']= insured['smoker'].astype("category")
insured['region']= insured['region'].astype("category")

# %%
insured.info() #gives the information about datatype and we can see obj has been converted to categorical
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   category
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   category
#  5   region    1338 non-null   category
#  6   expenses  1338 non-null   float64
# dtypes: category(3), float64(2), int64(2)
# memory usage: 46.3 KB

# %%
#to gets unique observations for each category variable
list_col= insured.select_dtypes(['category']).columns
list_col
# Out:
# Index(['sex', 'smoker', 'region'], dtype='object')

# %%
# to get columns name of integer type of columns
list_col1=  insured.select_dtypes(['int']).columns
list_col1
# Out:
# Index(['age', 'children'], dtype='object')

# %%
#to get the columns name of float type variable
list_col2= insured.select_dtypes(['float']).columns
list_col2
# Out:
# Index(['bmi', 'expenses'], dtype='object')

# %%
insured['sex'].value_counts()   #to get the count of sex columns
# Out:
# male      676
# female    662
# Name: sex, dtype: int64

# %%
insured['smoker'].value_counts()   #to get the counts of smoker
# Out:
# no     1064
# yes     274
# Name: smoker, dtype: int64

# %%
insured['region'].value_counts()   #to get the count of region
# Out:
# southeast    364
# northwest    325
# southwest    325
# northeast    324
# Name: region, dtype: int64

# %%
dict(insured['region'].value_counts())    #to convert into the dictionary
# Out:
# {'southeast': 364, 'northwest': 325, 'southwest': 325, 'northeast': 324}

# %%
for i in list_col:         #to iterate over each columns in list_col
    print(i)
# Out:
# sex
# smoker
# region

# %%
for i in list_col:
    print(dict(insured[i].value_counts()))
# Out:
# {'male': 676, 'female': 662}
# {'no': 1064, 'yes': 274}
# {'southeast': 364, 'northwest': 325, 'southwest': 325, 'northeast': 324}

# %%
for i in range(len(list_col)):
    print(insured[list_col[i]].value_counts())
# Out:
# male      676
# female    662
# Name: sex, dtype: int64
# no     1064
# yes     274
# Name: smoker, dtype: int64
# southeast    364
# northwest    325
# southwest    325
# northeast    324
# Name: region, dtype: int64

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %% [markdown]
# # Univariate analysis

# %%
# Function to create barplots that indicate percentage for each category.
def bar_perc(plot, feature):
    total = len(feature) # length of the column
    for p in plot.patches:
        percentage = '{:.1f}%'.format(100 * p.get_height()/total) # percentage of each class of the category 
        #should be formatted in floating no. with 1 decimal value
        x = p.get_x() + p.get_width() / 2 - 0.05 # width of the plot
        y = p.get_y() + p.get_height()           # hieght of the plot
        plot.annotate(percentage, (x, y), size = 12) # annotate the percentage

# %%
#this code is to determine the count of individuals who are categorized as 'Female' sex in the DataFrame insured.
len(insured[insured['sex']== 'female'])
# Out:
# 662

# %%
len(insured[insured['sex'] == 'male'])
# Out:
# 676

# %%
#to count the numbers of male and female and create a bar plot
no_of_male = len(insured[insured['sex'] == 'male'])
no_of_female = len(insured[insured['sex'] == 'female'])

plt.bar(['male','female'],[no_of_male,no_of_female],color = ['r','g'],label = ['Male','Female'])
plt.legend()#without legend the plot may be less informative
plt.title("Distribution of Sex in the Insured Dataset")
plt.show()

# %%
plot_data = dict(insured['sex'].value_counts())  #We can plot the bar directly using value_counts
print(plot_data)
plt.bar(['Male','Female'],[plot_data['male'],plot_data['female']],color = ['b','y'],label = ['Male','Female'])
plt.legend()
plt.show()
# Out:
# {'male': 676, 'female': 662}

# %%
insured['sex'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
#for smokers
#counts the no of smokers and non smokers and create a bar plot to visualize data
no_of_smokers = len(insured[insured['smoker'] == "yes"])
no_of_nonsmokers = len(insured[insured['smoker'] == "no"])

plt.bar(["yes","no"],[no_of_smokers, no_of_nonsmokers], color = ['r','g'], label=["smokers", "Non-smokers"])
plt.title('Distribution of Smoking Status Among Insured Individuals')
plt.legend()
plt.show()

# %%
plot_data.keys()
# Out:
# dict_keys(['male', 'female'])

# %%
plot_data.values()
# Out:
# dict_values([676, 662])

# %%
plot_data = dict(insured['smoker'].value_counts())
print(plot_data)
plt.bar(plot_data.keys(),plot_data.values(),color = ['r','g'],label = plot_data.keys())
plt.legend()
plt.show()
# plot_data
# plot_data.keys()
# Out:
# {'no': 1064, 'yes': 274}

# %%
insured['smoker'].value_counts().plot.pie()#plotting the pie charts 
plt.title('Distribution of Smoking Status Among Insured Individuals')
# Out:
# Text(0.5, 1.0, 'Distribution of Smoking Status Among Insured Individuals')

# %%
len(set(insured['region']))
# Out:
# 4

# %%
insured['region'].value_counts().plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# # Analyzing categorical data

# %%
data = {}
list_col=  insured.select_dtypes(['category']).columns
for i in range(len(list_col)):
  values = list(insured[list_col[i]].value_counts())
  subcategory = list(insured[list_col[i]].value_counts().index)
  # data['x'] = values
  data[list_col[i]] = [subcategory,values]
  # print(subcategory,values)

print(data)
# Out:
# {'sex': [['male', 'female'], [676, 662]], 'smoker': [['no', 'yes'], [1064, 274]], 'region': [['southeast', 'northwest', 'southwest', 'northeast'], [364, 325, 325, 324]]}

# %%
# #Alternate
print(data['region'])
plt.bar(data['region'][0],data['region'][1],
         label=['southeast', 'northwest', 'southwest', 'northeast'],
        color = ['r','b','g','k'])
plt.title('Region')
plt.legend()
plt.show()
# Out:
# [['southeast', 'northwest', 'southwest', 'northeast'], [364, 325, 325, 324]]

# %% [markdown]
# # Bivariate and Multi-variate analysis

# %%
insured
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %%
corr_insured = insured[['age','bmi','children', 'expenses']] #quantitative variable

# %%
corr_insured.corr()
# Out:
#                age       bmi  children  expenses
# age       1.000000  0.109341  0.042469  0.299008
# bmi       0.109341  1.000000  0.012645  0.198576
# children  0.042469  0.012645  1.000000  0.067998
# expenses  0.299008  0.198576  0.067998  1.000000

# %%
plt.figure(figsize=(15,10))  #width 15 units and 10 height
sns.heatmap(corr_insured.corr(), annot= True)  #adding annotation to each cell of heat map
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.pairplot(data=insured) #relationship between 2 variables
plt.show()   #distribution plot

# %%
#Sex count plot
plt.figure(figsize=(13,5))
ax=sns.countplot(x='smoker',hue='sex',data=insured) #hue function used to divide
# bar_perc(ax,insured['smoker'])

# %%
plt.figure(figsize= (13,5))
ax= sns.countplot(x='smoker', hue= 'sex', data= insured)
bar_perc(ax, insured['smoker'])

# %%
#smoker vs charges
sns.barplot(x=insured.smoker,y=insured.expenses).set(title="Smoker vs Charges")
# Out:
# [Text(0.5, 1.0, 'Smoker vs Charges')]

# %%
#region vs smoker
plt.figure(figsize=(10,5))
ax=sns.countplot(x='region',hue='smoker',data=insured)
bar_perc(ax,insured['smoker'])
ax.set(title="Region vs Smoker")
# Out:
# [Text(0.5, 1.0, 'Region vs Smoker')]

# %%
# #smoker vs region
plt.figure(figsize=(10,5))
ax=sns.countplot(x='smoker',hue='region',data=insured)
bar_perc(ax,insured['region'])
ax.set(title="Smoker vs Region")
# Out:
# [Text(0.5, 1.0, 'Smoker vs Region')]

# %%
#sex vs Region
plt.figure(figsize=(13,5))
ax=sns.countplot(x='region',hue='sex',data=insured,palette='spring')
bar_perc(ax,insured['sex'])
ax.set(title="Sex vs Region")
# Out:
# [Text(0.5, 1.0, 'Sex vs Region')]

# %%
insured.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %% [markdown]
# # Groupby

# %%
insured.groupby(insured.sex).bmi.mean()  #to calculate the bmi mean of each sex
# Out:
# sex
# female    30.379758
# male      30.945266
# Name: bmi, dtype: float64

# %%
insured.groupby(insured.sex).children.mean()  #to calculate the children mean of each sex
# Out:
# sex
# female    1.074018
# male      1.115385
# Name: children, dtype: float64

# %%
insured.groupby(insured.sex).expenses.mean()    #to calculate the expenses mean of each sex
# Out:
# sex
# female    12569.578897
# male      13956.751420
# Name: expenses, dtype: float64

# %%
insured.groupby(insured.region).expenses.mean()   #to calculate the expenses mean of each region
# Out:
# region
# northeast    13406.384691
# northwest    12417.575169
# southeast    14735.411538
# southwest    12346.937908
# Name: expenses, dtype: float64

# %%
insured.groupby(insured.smoker).expenses.mean()    #to calculate the expenses mean of smoker
# Out:
# smoker
# no      8434.268449
# yes    32050.231971
# Name: expenses, dtype: float64

# %%
plot_data = dict(insured.groupby(insured['region']).expenses.mean())
plot_key = list(plot_data.keys()) #contain region
plot_value = list(plot_data.values()) #contain mean expenses
print(plot_key)
print(plot_value)
print(plot_data)
# Out:
# ['northeast', 'northwest', 'southeast', 'southwest']
# [13406.384691358024, 12417.57516923077, 14735.411538461538, 12346.937907692307]
# {'northeast': 13406.384691358024, 'northwest': 12417.57516923077, 'southeast': 14735.411538461538, 'southwest': 12346.937907692307}

# %%
insured.groupby(insured['region']).expenses.mean().plot.bar() #using matplotlib
# Out:
# <Axes: xlabel='region'>

# %%
#Plot of sex and expenses
sns.barplot(x=insured.sex,y=insured.expenses).set(title='sex Vs expenses') #using seaborn
# Out:
# [Text(0.5, 1.0, 'sex Vs expenses')]

# %%
sns.barplot(x= insured.region, y=insured.expenses).set(title= "Region vs Expenses")
# Out:
# [Text(0.5, 1.0, 'Region vs Expenses')]

# %% [markdown]
# # Multivariate

# %%
#multivariate
plt.figure(figsize=(15,7))
sns.lineplot(x = insured["sex"], y =insured["expenses"],hue=insured["region"],ci=1).set(title= 'Expenses of males and females wrt Region')
#ci = confidence intervalfor estamating mean at each points =(mean+-z*sd/root n)
plt.legend(bbox_to_anchor=(0.5, 1)) #fixing the position of legend 0.5 horizontally and at the top 1 vertically
plt.show()

# %%
#multivariate
plt.figure(figsize=(15,7))
sns.lineplot(x = insured["sex"], y =insured["bmi"],hue=insured["region"],ci=1).set(title= 'BMI of males and females wrt region')
#ci = confidence intervalfor estamating mean at each points =(mean+-z*sd/root n)
plt.legend(bbox_to_anchor=(0.5, 1)) #fixing the position of legend 0.5 horizontally and at the top 1 vertically
plt.show()

# %%
#multivariate
plt.figure(figsize=(15,7))
sns.lineplot(x = insured["sex"], y =insured["expenses"],hue=insured["smoker"],ci=1).set(title= 'Expenses of males and females wrt Smoker')
#ci = confidence intervalfor estamating mean at each points =(mean+-z*sd/root n)
plt.legend(bbox_to_anchor=(0.5, 1)) #fixing the position of legend 0.5 horizontally and at the top 1 vertically
plt.show()

# %%
#Cross tab: statistical tool used to summarize or analyze 2 or more categorical variables
reg_sex_expenses =pd.crosstab(index=insured['region'], columns=insured.sex  , values=insured.expenses, aggfunc='mean')
reg_sex_expenses  # is cross-tabulation table that shows the mean expenses for each combination of sex and region.

#aggfunc is aggregation function which is mean in this case
# Out:
# sex              female          male
# region
# northeast  12953.203106  13854.005767
# northwest  12479.870244  12354.119317
# southeast  13499.669257  15879.617354
# southwest  11274.411667  13412.884233

# %%
sex_reg_expenses= pd.crosstab(index= insured['sex'], columns= insured.region, values= insured.expenses, aggfunc= 'mean')
sex_reg_expenses
# Out:
# region     northeast     northwest     southeast     southwest
# sex
# female  12953.203106  12479.870244  13499.669257  11274.411667
# male    13854.005767  12354.119317  15879.617354  13412.884233

# %%
reg_sex_expenses.plot(kind='bar',title="Region Vs Sex Vs Expenses")
plt.legend(loc='upper left')
plt.show()

# %%
sex_reg_expenses.plot(kind= 'bar', title= 'Sex vs Region vs Expenses')
plt.legend(loc= 'upper right')
plt.show()

# %% [markdown]
# # Converting quantitative data to qualitative

# %%
insured
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %%
insured.describe()
# Out:
#                age          bmi     children      expenses
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.665471     1.094918  13270.422414
# std      14.049960     6.098382     1.205493  12110.011240
# min      18.000000    16.000000     0.000000   1121.870000
# 25%      27.000000    26.300000     0.000000   4740.287500
# 50%      39.000000    30.400000     1.000000   9382.030000
# 75%      51.000000    34.700000     2.000000  16639.915000
# max      64.000000    53.100000     5.000000  63770.430000

# %%
#creating groups of age
#CUT function is used for converting quantitative data to qualitative
category = pd.cut(insured.age,bins=[10,15,20,25,30,35,40,45,50,55,60,65],labels=['10-15','15-20','20-25','25-30','30-35','35-40','40-45','45-50','50-55','55-60','60-65'])
category
#insured.insert(1,'AgeGroup',category)
# Out:
# 0       15-20
# 1       15-20
# 2       25-30
# 3       30-35
# 4       30-35
#         ...
# 1333    45-50
# 1334    15-20
# 1335    15-20
# 1336    20-25
# 1337    60-65
# Name: age, Length: 1338, dtype: category
# Categories (11, object): ['10-15' < '15-20' < '20-25' < '25-30' ... '45-50' < '50-55' < '55-60' < '60-65']

# %%
insured.insert(1,'age group', category) # to put 1 index agecolumn

# %%
insured
# Out:
#       age age group     sex   bmi  children smoker     region  expenses
# 0      19     15-20  female  27.9         0    yes  southwest  16884.92
# 1      18     15-20    male  33.8         1     no  southeast   1725.55
# 2      28     25-30    male  33.0         3     no  southeast   4449.46
# 3      33     30-35    male  22.7         0     no  northwest  21984.47
# 4      32     30-35    male  28.9         0     no  northwest   3866.86
# ...   ...       ...     ...   ...       ...    ...        ...       ...
# 1333   50     45-50    male  31.0         3     no  northwest  10600.55
# 1334   18     15-20  female  31.9         0     no  northeast   2205.98
# 1335   18     15-20  female  36.9         0     no  southeast   1629.83
# 1336   21     20-25  female  25.8         0     no  southwest   2007.95
# 1337   61     60-65  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 8 columns]

# %%
age_group = insured.groupby('age group').expenses.mean()
age_group
# Out:
# age group
# 10-15             NaN
# 15-20     8713.482771
# 20-25     9529.919643
# 25-30    10086.132754
# 30-35    10929.364692
# 35-40    12366.023071
# 40-45    14538.651241
# 45-50    15013.603472
# 50-55    16988.005500
# 55-60    17145.495040
# 60-65    21063.163407
# Name: expenses, dtype: float64

# %%
age_group.plot(kind='bar',title="Agebins vs Avg expenses")
# Out:
# <Axes: title={'center': 'Agebins vs Avg expenses'}, xlabel='age group'>

# %%
insured.groupby(['sex', 'smoker','age group']).expenses.mean()
# Out:
# sex     smoker  age group
# female  no      10-15                 NaN
#                 15-20         3583.173651
#                 20-25         5458.693571
#                 25-30         5812.940000
#                 30-35         5743.724259
#                 35-40         7191.163529
#                 40-45         8662.338302
#                 45-50        10876.252459
#                 50-55        12982.955574
#                 55-60        13824.443103
#                 60-65        15674.126000
#         yes     10-15                 NaN
#                 15-20        24094.754118
#                 20-25        29027.281818
#                 25-30        22127.861667
#                 30-35        35965.668000
#                 35-40        28712.160000
#                 40-45        31807.159333
#                 45-50        30291.370909
#                 50-55        38682.564000
#                 55-60        37939.476000
#                 60-65        36883.435000
# ...

# %%
insured.groupby(['sex', 'smoker','age group']).expenses.mean().unstack() #unstack is used to reshape in dataframe
# Out:
# age group      10-15         15-20         20-25         25-30         30-35  \
# sex    smoker
# female no        NaN   3583.173651   5458.693571   5812.940000   5743.724259
#        yes       NaN  24094.754118  29027.281818  22127.861667  35965.668000
# male   no        NaN   3247.222656   3891.321724   5145.062830   6527.399000
#        yes       NaN  27421.142273  32233.676667  29663.997222  26539.354375
#
# age group             35-40         40-45         45-50         50-55  \
# sex    smoker
# female no       7191.163529   8662.338302  10876.252459  12982.955574
#        yes     28712.160000  31807.159333  30291.370909  38682.564000
# male   no       7142.125625   8222.899608  10453.254909  12407.019455
#        yes     32272.977500  35345.334444  34727.847059  36939.197857
#
# age group             55-60         60-65
# sex    smoker
# female no      13824.443103  15674.126000
#        yes     37939.476000  36883.435000
# male   no      12597.976531  15050.056765
# ...

# %%
insured.groupby(['sex','smoker','age group']).expenses.mean().unstack().plot(kind='bar',title= 'Avg expenses vs Age group')
# Out:
# <Axes: title={'center': 'Avg expenses vs Age group'}, xlabel='sex,smoker'>

# %%
insured.groupby(['sex','age group','smoker']).expenses.mean().unstack().plot(kind='bar',title= 'Avg expenses vs Smoker')
# Out:
# <Axes: title={'center': 'Avg expenses vs Smoker'}, xlabel='sex,age group'>

# %%
plt.figure(figsize=(15,7))
sns.barplot(x=insured["region"],y=insured["expenses"],hue=insured['sex'],ci=0).set(title= 'Region vs expenses of Males and Females')
plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()

# %%
sns.barplot(x='smoker',y='bmi',hue='sex',data=insured).set(title="Smoker vs BMI vs Sex" )
# Out:
# [Text(0.5, 1.0, 'Smoker vs BMI vs Sex')]

# %% [markdown]
# # Relational plot

# %%
sns.relplot(x=insured['region'], y=insured["expenses"], hue=insured['sex'], size=  insured['smoker'],
            sizes=(40, 400), palette="spring", #circle size
            height=6, data=insured).set(title='Expenses by smokers, sex, region');

# %%
sns.relplot(x=insured['expenses'], y=insured["bmi"], hue=insured['sex'], size=  insured['region'],
            sizes=(40, 400), palette="spring", #circle size
            height=6, data=insured).set(title='Expenses with bmi,sex, region');

# %%
sns.relplot(x=insured['age group'], y=insured["expenses"], hue=insured['region'], size=  insured['smoker'],
            sizes=(40, 400), palette="spring", #circle size
            height=6, data=insured).set(title='Expenses according to age group,smoker, region');

# %%
sns.relplot(x=insured['age group'], y=insured["expenses"], hue=insured['sex'], size=  insured['smoker'],
            sizes=(40, 400), palette="spring", #circle size
            height=6, data=insured).set(title='Expenses by smokers, sex, age group');

# %% [markdown]
# # Hypothesis Testing

# %% [markdown]
# # 1.Prove (or disprove) that the medical claims made by the people who smoke is greater than those who don't?

# %% [markdown]
# # <font size=3><b>    Step 1: Define null and alternative hypothesis</b></font><br>
#  𝐻0:𝜇1<=𝜇2
#   The average charges of smokers is less than or equal to nonsmokers
#
#  𝐻𝑎:𝜇1>𝜇2
#   The average charges of smokers is greater than nonsmokers

# %% [markdown]
# # <font size=3><b>Step 2: Decide the significance level. If P values is less than alpha reject the null hypothesis.</b></font>
# α = 0.05

# %% [markdown]
# # Step 3: Identify the test
# Standard deviation of the population is not known ,will perform a T stat test . The > sign in alternate hypothesis indicate test is right tailed, that is all z values that would cause us to reject null hypothesis are in just one tail to the right of sampling distribution curve.

# %% [markdown]
# # <div class ="alert alert-block alert-info">
#   #  <font size=3><b>Step 4: Calculate the test-statistics and p-value</b></font>

# %%
smoker=insured.loc[insured.smoker=="yes"]
smoker.head()
# Out:
#     age age group     sex   bmi  children smoker     region  expenses
# 0    19     15-20  female  27.9         0    yes  southwest  16884.92
# 11   62     60-65  female  26.3         0    yes  southeast  27808.73
# 14   27     25-30    male  42.1         0    yes  southeast  39611.76
# 19   30     25-30    male  35.3         0    yes  southwest  36837.47
# 23   34     30-35  female  31.9         1    yes  northeast  37701.88

# %%
smoker.count()
# Out:
# age          274
# age group    274
# sex          274
# bmi          274
# children     274
# smoker       274
# region       274
# expenses     274
# dtype: int64

# %%
nonsmoker=insured.loc[insured.smoker=='no']
nonsmoker.head()
# Out:
#    age age group     sex   bmi  children smoker     region  expenses
# 1   18     15-20    male  33.8         1     no  southeast   1725.55
# 2   28     25-30    male  33.0         3     no  southeast   4449.46
# 3   33     30-35    male  22.7         0     no  northwest  21984.47
# 4   32     30-35    male  28.9         0     no  northwest   3866.86
# 5   31     30-35  female  25.7         0     no  southeast   3756.62

# %%
nonsmoker.count()
# Out:
# age          1064
# age group    1064
# sex          1064
# bmi          1064
# children     1064
# smoker       1064
# region       1064
# expenses     1064
# dtype: int64

# %%
# Adjusting the size of the rows to be equal
nonsmoker = nonsmoker[0:274]
charges_yes = smoker.expenses
charges_no = nonsmoker.expenses

# %%
print(f'Average Cost charged to Insurance for smoker is {charges_yes.mean()} and nonsmoker is {charges_no.mean()} ')
# Out:
# Average Cost charged to Insurance for smoker is 32050.23197080292 and nonsmoker is 8460.786167883212

# %%
#smoker
sns.boxplot(x= insured.expenses, y= insured.smoker, data= insured).set(title= "Fig:1 Smoker vs Charges")
# Out:
# [Text(0.5, 1.0, 'Fig:1 Smoker vs Charges')]

# %%
charges_no
# Out:
# 1       1725.55
# 2       4449.46
# 3      21984.47
# 4       3866.86
# 5       3756.62
#          ...
# 350    11830.61
# 351     8932.08
# 352     3554.20
# 353    12404.88
# 354    14133.04
# Name: expenses, Length: 274, dtype: float64

# %%
alpha = 0.05
t_statistic_1, p_value_1 = stats.ttest_ind(charges_yes, charges_no) 
p_value_onetail=p_value_1/2

print("Test statistic = {} , Pvalue ={} , OnetailPvalue = {}".format(t_statistic_1,p_value_1, p_value_onetail ))
# Out:
# Test statistic = 29.96693762930951 , Pvalue =2.11900162618799e-117 , OnetailPvalue = 1.059500813093995e-117

# %%
if p_value_1 < alpha :
    print(f"Conclusion:Since P value {p_value_onetail} is less than alpha {alpha} " )
    # print("Reject Null Hypothesis that Average charges for smokers are less than or equal to nonsmoker.")

else:
    print("Conclusion:Since P value {} is greater than alpha {} ". format (p_value_onetail,alpha))
    # print("Failed to Reject Null Hypothesis that Average charges for smokers are less than nonsmoker.")
# Out:
# Conclusion:Since P value 1.059500813093995e-117 is less than alpha 0.05

# %% [markdown]
# # Step 5: Decide whethere to reject or failed to reject null hypothesis
# We reject the null hypothesis and can conclude that people who smoke have on an average larger medical claim compared to people who don't smoke. Similar result can also been seen in Fig no.1 Smokers Vs Charges
